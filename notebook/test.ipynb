# %%
from telegram_bot.ollama.llm import Agent

agent = Agent()

# %%
agent.answer("Hi")
# Out:
# ('Hi there! How’s your day going so far? Is there anything I can help you with today?',
#  {'provider': 'ollama',
#   'model': 'gemma3:4b',
#   'operation': 'generate',
#   'duration': 2.826136299991049,
#   'input_tokens': 24,
#   'output_tokens': 23})
